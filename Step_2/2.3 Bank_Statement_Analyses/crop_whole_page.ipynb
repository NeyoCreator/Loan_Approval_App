# %%
#!pip install pdf2image
#importing the libraries
import cv2
import numpy as np
import pytesseract as tess
tess.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

# %% [markdown]
# # __Convert the Page__

# %%
#Function that extracts data from the pdf
def extract_data(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    threshed = cv2.adaptiveThreshold(gray,255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,17)
    text1 = tess.image_to_data(threshed,output_type='data.frame')
    text2 = tess.image_to_string(threshed)
    text = text1[text1.conf != -1]
    return text2

# %%
from pdf2image import convert_from_path

# %%
image = convert_from_path('account_statement.pdf')
for i in range(len(image)):
   
      # Save pages as images in the pdf
    image[i].save('work'+ str(i) +'.jpg', 'JPEG')


# we are not going to start at zero since all the files are not the same

# %%
#Create a function that takes in an image and returns 4 values 

def extract_vertical_data(img):
    global description_arr
    
    #Obtain the file 
    original_image = cv2.imread(img)

    #Get posting date
    # cropped_image_posting = original_image[40:2050, 60:250]
    # posting_data = extract_data(cropped_image_posting)
    # posting_arr = posting_data.split("\n")

    # posting_arr += posting_arr

    # #Get transaction date 
    # cropped_image_transaction = original_image[40:2050, 250:400]
    # transaction_data = extract_data(cropped_image_transaction)
    # transaction_arr = transaction_data.split("\n")

    #Get description
    cropped_image_description = original_image[40:2050,400:1100]
    description_data = extract_data(cropped_image_description)
    description_arr = description_data.split("\n")
    description_arr += description_arr

    # #Get Balance 
    # cropped_balance = original_image[40:2050, 1400:1800]
    # balance_data = extract_data(cropped_balance)
    # balance_arr = balance_data.split("\n")

    
    return

# %%
x = 0
while  x < 3 :
    x +=1
    image = 'work'+str(x)+".jpg"
    print('work'+str(x)+".jpg")
    extract_vertical_data(image)
# Out:
# work1.jpg
# work2.jpg
# work3.jpg

# %%
description_arr
# Out:
# ['ATM Cash Withdrawal Fee',
#  '',
#  'SMS Notification Fee',
#  '',
#  'Pep Cell Pretoria (Card 5813)',
#  '',
#  'Online purchase: Payd Vodacom Express R Gauteng (Card',
#  '5813)',
#  '',
#  'ATM Cash Withdrawal Bp Mahube Pretoria Gpza',
#  '',
#  'ATM Cash Withdrawal Fee',
#  '',
#  'SMS Notification Fee',
#  '',
#  'Pick n Pay Mamelodi (Card 5813)',
#  'ATM Declined Withdrawal Fee',
#  'ATM Balance Enquiry Fee',
#  'Payment Received T Ndlovu .',
#  'SMS Notification Fee Capitec',
#  'Online purchase: Payd Vodacom Express R Gauteng (Card',
#  '',
#  '5813)',
#  'Pick n Pay Mamelodi (Card 5813) 26/03',
#  'S813) purchase: Payd Vodacom Express R Gauteng (a§-anch:',
#  'Online purchase: Payd Vodacom Express R Gautdng (Card) eviC!',
#  '5813)',
#  'Online purchase: Payd Vodacom Express R Gautehg (Card',
#  '',
#  '5813)',
#  '',
#  'Online purchase: Payd Vodacom Express R Gaute tear',
#  '5813)',
#  '',
#  'Online purchase: Payd Vodacom Express R Gauteng (Card',
#  '5813)',
#  '',
# ...

# %%
image = cv2.imread("work.jpg")
plt.imshow(image)
